# %%
# ============================================================
# 🍃 Guava Maturity Classification using DenseNet121 (Digital Images)
# ============================================================

import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os

# ============================================================
# Dataset Paths (UPDATE these paths)
# ============================================================
train_dir = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split for digital\train"
val_dir   = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split for digital\val"
test_dir  = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split for digital\test"

# ============================================================
# Image Parameters
# ============================================================
img_size = (224, 224)
batch_size = 32
epochs = 50

# ============================================================
# Data Generators
# ============================================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen  = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ============================================================
# Model Definition — DenseNet121
# ============================================================
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base layers
for layer in base_model.layers:
    layer.trainable = False

# Custom classifier head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.4)(x)
output = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# Callbacks
# ============================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_densenet_digital_guava.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# ============================================================
# Training
# ============================================================
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    callbacks=[early_stop, checkpoint, reduce_lr]
)

# ============================================================
# Evaluation on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# ============================================================
# Save Final Model
# ============================================================
model.save("densenet121_digital_guava_final.h5")
print("💾 Model saved as 'densenet121_digital_guava_final.h5'")

# ============================================================
# Plot Accuracy
# ============================================================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('DenseNet121 Guava Maturity (Digital Images) Accuracy')
plt.show()
# Out:
# Found 6531 images belonging to 3 classes.
# Found 1398 images belonging to 3 classes.
# Found 1404 images belonging to 3 classes.
# Epoch 1/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3597 - loss: 1.3676
# Epoch 1: val_accuracy improved from None to 0.49499, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 636s 3s/step - accuracy: 0.3837 - loss: 1.2899 - val_accuracy: 0.4950 - val_loss: 0.9857 - learning_rate: 1.0000e-04
# Epoch 2/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4479 - loss: 1.1389
# Epoch 2: val_accuracy improved from 0.49499 to 0.60014, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 609s 3s/step - accuracy: 0.4722 - loss: 1.0962 - val_accuracy: 0.6001 - val_loss: 0.8653 - learning_rate: 1.0000e-04
# Epoch 3/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5290 - loss: 0.9731
# Epoch 3: val_accuracy improved from 0.60014 to 0.71245, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 638s 3s/step - accuracy: 0.5466 - loss: 0.9492 - val_accuracy: 0.7124 - val_loss: 0.7676 - learning_rate: 1.0000e-04
# Epoch 4/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5820 - loss: 0.8814
# Epoch 4: val_accuracy improved from 0.71245 to 0.76395, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 605s 3s/step - accuracy: 0.5895 - loss: 0.8673 - val_accuracy: 0.7639 - val_loss: 0.7067 - learning_rate: 1.0000e-04
# Epoch 5/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6330 - loss: 0.8036
# Epoch 5: val_accuracy improved from 0.76395 to 0.78684, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 607s 3s/step - accuracy: 0.6440 - loss: 0.7888 - val_accuracy: 0.7868 - val_loss: 0.6600 - learning_rate: 1.0000e-04
# Epoch 6/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6450 - loss: 0.7854
# Epoch 6: val_accuracy improved from 0.78684 to 0.79685, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 605s 3s/step - accuracy: 0.6552 - loss: 0.7708 - val_accuracy: 0.7969 - val_loss: 0.6271 - learning_rate: 1.0000e-04
# Epoch 7/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6802 - loss: 0.7336
# Epoch 7: val_accuracy improved from 0.79685 to 0.81116, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 606s 3s/step - accuracy: 0.6817 - loss: 0.7300 - val_accuracy: 0.8112 - val_loss: 0.6020 - learning_rate: 1.0000e-04
# Epoch 8/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7005 - loss: 0.7096
# Epoch 8: val_accuracy did not improve from 0.81116
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 601s 3s/step - accuracy: 0.7045 - loss: 0.6995 - val_accuracy: 0.8054 - val_loss: 0.5859 - learning_rate: 1.0000e-04
# Epoch 9/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6992 - loss: 0.7010
# Epoch 9: val_accuracy did not improve from 0.81116
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 606s 3s/step - accuracy: 0.7102 - loss: 0.6810 - val_accuracy: 0.8054 - val_loss: 0.5736 - learning_rate: 1.0000e-04
# Epoch 10/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7124 - loss: 0.6575
# Epoch 10: val_accuracy improved from 0.81116 to 0.81974, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 601s 3s/step - accuracy: 0.7164 - loss: 0.6558 - val_accuracy: 0.8197 - val_loss: 0.5517 - learning_rate: 1.0000e-04
# Epoch 11/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7262 - loss: 0.6548
# Epoch 11: val_accuracy did not improve from 0.81974
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7348 - loss: 0.6419 - val_accuracy: 0.8162 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 12/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7349 - loss: 0.6206
# Epoch 12: val_accuracy did not improve from 0.81974
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7380 - loss: 0.6238 - val_accuracy: 0.8155 - val_loss: 0.5354 - learning_rate: 1.0000e-04
# Epoch 13/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7423 - loss: 0.6197
# Epoch 13: val_accuracy improved from 0.81974 to 0.82403, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 604s 3s/step - accuracy: 0.7417 - loss: 0.6235 - val_accuracy: 0.8240 - val_loss: 0.5231 - learning_rate: 1.0000e-04
# Epoch 14/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7509 - loss: 0.6069
# Epoch 14: val_accuracy did not improve from 0.82403
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 601s 3s/step - accuracy: 0.7467 - loss: 0.6081 - val_accuracy: 0.8162 - val_loss: 0.5236 - learning_rate: 1.0000e-04
# Epoch 15/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7556 - loss: 0.5940
# Epoch 15: val_accuracy did not improve from 0.82403
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 605s 3s/step - accuracy: 0.7521 - loss: 0.5965 - val_accuracy: 0.8155 - val_loss: 0.5144 - learning_rate: 1.0000e-04
# Epoch 16/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7508 - loss: 0.6016
# Epoch 16: val_accuracy did not improve from 0.82403
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7498 - loss: 0.5971 - val_accuracy: 0.8183 - val_loss: 0.5099 - learning_rate: 1.0000e-04
# Epoch 17/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7633 - loss: 0.5938
# Epoch 17: val_accuracy improved from 0.82403 to 0.82475, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 603s 3s/step - accuracy: 0.7558 - loss: 0.5954 - val_accuracy: 0.8247 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 18/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7679 - loss: 0.5706
# Epoch 18: val_accuracy improved from 0.82475 to 0.82690, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 601s 3s/step - accuracy: 0.7578 - loss: 0.5844 - val_accuracy: 0.8269 - val_loss: 0.4986 - learning_rate: 1.0000e-04
# Epoch 19/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7599 - loss: 0.5771
# Epoch 19: val_accuracy did not improve from 0.82690
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7613 - loss: 0.5750 - val_accuracy: 0.8233 - val_loss: 0.4974 - learning_rate: 1.0000e-04
# Epoch 20/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7592 - loss: 0.5598
# Epoch 20: val_accuracy improved from 0.82690 to 0.82833, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7570 - loss: 0.5706 - val_accuracy: 0.8283 - val_loss: 0.4908 - learning_rate: 1.0000e-04
# Epoch 21/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7775 - loss: 0.5582
# Epoch 21: val_accuracy did not improve from 0.82833
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 602s 3s/step - accuracy: 0.7703 - loss: 0.5659 - val_accuracy: 0.8262 - val_loss: 0.4909 - learning_rate: 1.0000e-04
# Epoch 22/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7659 - loss: 0.5675
# Epoch 22: val_accuracy improved from 0.82833 to 0.83262, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 601s 3s/step - accuracy: 0.7665 - loss: 0.5671 - val_accuracy: 0.8326 - val_loss: 0.4851 - learning_rate: 1.0000e-04
# Epoch 23/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7839 - loss: 0.5516
# Epoch 23: val_accuracy did not improve from 0.83262
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.7735 - loss: 0.5644 - val_accuracy: 0.8197 - val_loss: 0.4872 - learning_rate: 1.0000e-04
# Epoch 24/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7801 - loss: 0.5572
# Epoch 24: val_accuracy did not improve from 0.83262
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7823 - loss: 0.5497 - val_accuracy: 0.8283 - val_loss: 0.4810 - learning_rate: 1.0000e-04
# Epoch 25/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7804 - loss: 0.5419
# Epoch 25: val_accuracy did not improve from 0.83262
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7711 - loss: 0.5537 - val_accuracy: 0.8312 - val_loss: 0.4778 - learning_rate: 1.0000e-04
# Epoch 26/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7767 - loss: 0.5456
# Epoch 26: val_accuracy did not improve from 0.83262
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7777 - loss: 0.5464 - val_accuracy: 0.8240 - val_loss: 0.4785 - learning_rate: 1.0000e-04
# Epoch 27/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7843 - loss: 0.5300
# Epoch 27: val_accuracy improved from 0.83262 to 0.83548, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 600s 3s/step - accuracy: 0.7830 - loss: 0.5374 - val_accuracy: 0.8355 - val_loss: 0.4732 - learning_rate: 1.0000e-04
# Epoch 28/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7863 - loss: 0.5322
# Epoch 28: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7778 - loss: 0.5471 - val_accuracy: 0.8255 - val_loss: 0.4716 - learning_rate: 1.0000e-04
# Epoch 29/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7739 - loss: 0.5575
# Epoch 29: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7768 - loss: 0.5531 - val_accuracy: 0.8298 - val_loss: 0.4718 - learning_rate: 1.0000e-04
# Epoch 30/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7876 - loss: 0.5327
# Epoch 30: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 595s 3s/step - accuracy: 0.7832 - loss: 0.5359 - val_accuracy: 0.8348 - val_loss: 0.4664 - learning_rate: 1.0000e-04
# Epoch 31/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7853 - loss: 0.5329
# Epoch 31: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.7876 - loss: 0.5293 - val_accuracy: 0.8340 - val_loss: 0.4662 - learning_rate: 1.0000e-04
# Epoch 32/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7758 - loss: 0.5403
# Epoch 32: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7780 - loss: 0.5403 - val_accuracy: 0.8333 - val_loss: 0.4634 - learning_rate: 1.0000e-04
# Epoch 33/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7882 - loss: 0.5277
# Epoch 33: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7830 - loss: 0.5350 - val_accuracy: 0.8219 - val_loss: 0.4676 - learning_rate: 1.0000e-04
# Epoch 34/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7815 - loss: 0.5442
# Epoch 34: val_accuracy did not improve from 0.83548
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.7833 - loss: 0.5377 - val_accuracy: 0.8233 - val_loss: 0.4635 - learning_rate: 1.0000e-04
# Epoch 35/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7922 - loss: 0.5296
# Epoch 35: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7922 - loss: 0.5308 - val_accuracy: 0.8312 - val_loss: 0.4616 - learning_rate: 3.0000e-05
# Epoch 36/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7931 - loss: 0.5278
# Epoch 36: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7817 - loss: 0.5383 - val_accuracy: 0.8312 - val_loss: 0.4597 - learning_rate: 3.0000e-05
# Epoch 37/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8004 - loss: 0.5044
# Epoch 37: val_accuracy did not improve from 0.83548
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7954 - loss: 0.5194 - val_accuracy: 0.8319 - val_loss: 0.4598 - learning_rate: 3.0000e-05
# Epoch 38/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7806 - loss: 0.5295
# Epoch 38: val_accuracy improved from 0.83548 to 0.83834, saving model to best_densenet_digital_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.7809 - loss: 0.5322 - val_accuracy: 0.8383 - val_loss: 0.4577 - learning_rate: 3.0000e-05
# Epoch 39/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7906 - loss: 0.5242
# Epoch 39: val_accuracy did not improve from 0.83834
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 599s 3s/step - accuracy: 0.7893 - loss: 0.5267 - val_accuracy: 0.8333 - val_loss: 0.4576 - learning_rate: 3.0000e-05
# Epoch 40/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7900 - loss: 0.5231
# Epoch 40: val_accuracy did not improve from 0.83834
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 596s 3s/step - accuracy: 0.7905 - loss: 0.5240 - val_accuracy: 0.8305 - val_loss: 0.4592 - learning_rate: 3.0000e-05
# Epoch 41/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7898 - loss: 0.5354
# Epoch 41: val_accuracy did not improve from 0.83834
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 597s 3s/step - accuracy: 0.7919 - loss: 0.5295 - val_accuracy: 0.8312 - val_loss: 0.4585 - learning_rate: 9.0000e-06
# Epoch 42/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7836 - loss: 0.5277
# Epoch 42: val_accuracy did not improve from 0.83834
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 598s 3s/step - accuracy: 0.7853 - loss: 0.5323 - val_accuracy: 0.8312 - val_loss: 0.4587 - learning_rate: 9.0000e-06
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 39.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.8519 - loss: 0.4406
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Test Accuracy: 85.19%
# ✅ Test Loss: 0.4406
# 💾 Model saved as 'densenet121_digital_guava_final.h5'

# %%
# ============================================================
# 🍃 DenseNet121 — Testing Accuracy Evaluation (Digital Images)
# ============================================================

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# ============================================================
# Paths
# ============================================================
test_dir = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split for digital\test"
model_path = "best_densenet_digital_guava.h5"  # or use "densenet121_digital_guava_final.h5"

# ============================================================
# Load Model
# ============================================================
model = load_model(model_path)
print("✅ Model loaded successfully!")

# ============================================================
# Test Data Generator
# ============================================================
img_size = (224, 224)
batch_size = 32

test_datagen = ImageDataGenerator(rescale=1./255)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ============================================================
# Evaluate on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n🎯 Test Accuracy: {test_acc*100:.2f}%")
print(f"📉 Test Loss: {test_loss:.4f}")

# ============================================================
# Predictions & Detailed Metrics
# ============================================================
y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# Classification Report
print("\n📊 Classification Report (Test Data):")
print(classification_report(y_true, y_pred_classes, target_names=class_labels))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix — DenseNet121 (Test Set)")
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully!
# Found 1404 images belonging to 3 classes.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.8519 - loss: 0.4405
#
# 🎯 Test Accuracy: 85.19%
# 📉 Test Loss: 0.4405
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step
#
# 📊 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#     immature       0.93      0.89      0.91       490
#       mature       0.84      0.84      0.84       485
#  semi_mature       0.79      0.83      0.81       429
#
#     accuracy                           0.85      1404
#    macro avg       0.85      0.85      0.85      1404
# weighted avg       0.85      0.85      0.85      1404

# %%
# ============================================================
# 🍃 View Training Accuracy from History Object
# ============================================================

import matplotlib.pyplot as plt

# After training, you already have this:
# history = model.fit(...)

# ============================================================
# Print final training and validation accuracy
# ============================================================
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]

print(f"✅ Final Training Accuracy: {final_train_acc * 100:.2f}%")
print(f"✅ Final Validation Accuracy: {final_val_acc * 100:.2f}%")

# ============================================================
# Plot accuracy curves
# ============================================================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy — DenseNet121')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ✅ Final Training Accuracy: 78.53%
# ✅ Final Validation Accuracy: 83.12%

# %%
test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test_gen = test_datagen.flow_from_directory(
#       2     test_dir,
#       3     target_size=img_size,
#       4     batch_size=batch_size,
#       5     class_mode='categorical',
#       6     shuffle=False
#       7 )
#
# NameError: name 'test_datagen' is not defined

# %%
# ============================================================
# 🧩 Classification Report and Confusion Matrix
# ============================================================
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np

# Get true labels and predicted labels
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)

# Get class labels
class_labels = list(test_gen.class_indices.keys())

# Classification report
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - DenseNet121 (Digital Images)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 import numpy as np
#       8 # Get true labels and predicted labels
# ----> 9 y_true = test_gen.classes
#      10 y_pred_probs = model.predict(test_gen)
#      11 y_pred = np.argmax(y_pred_probs, axis=1)
#
# NameError: name 'test_gen' is not defined
