# %%
# ============================================================
# 🍃 Plant Disease Classification using DenseNet121 (3 Classes)
# ============================================================

import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os

# ============================================================
# Check for GPU (CUDA)
# ============================================================
print("🔹 TensorFlow Version:", tf.__version__)
print("🚀 GPU Available:", tf.config.list_physical_devices('GPU'))

# ============================================================
# Dataset Paths
# ============================================================
train_dir = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\GuavaDiseaseDataset\train"
val_dir   = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\GuavaDiseaseDataset\val"
test_dir  = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\GuavaDiseaseDataset\test"

# ============================================================
# Image Parameters
# ============================================================
img_size = (224, 224)
batch_size = 32
epochs = 50

# ============================================================
# Data Generators
# ============================================================
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen  = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ============================================================
# Model Definition — DenseNet121
# ============================================================
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base layers for transfer learning
for layer in base_model.layers:
    layer.trainable = False

# Custom classifier head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.4)(x)
output = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# Callbacks
# ============================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_densenet_disease.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# ============================================================
# Training
# ============================================================
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    callbacks=[early_stop, checkpoint, reduce_lr]
)

# ============================================================
# Evaluation on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# ============================================================
# Save Final Model
# ============================================================
model.save("densenet121_disease_final.h5")
print("💾 Model saved as 'densenet121_disease_final.h5'")

# ============================================================
# Plot Accuracy
# ============================================================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('DenseNet121 Disease Classification Accuracy')
plt.show()
# Out:
# 🔹 TensorFlow Version: 2.20.0
# 🚀 GPU Available: []
# Found 3091 images belonging to 3 classes.
# Found 926 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.
# Epoch 1/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3553 - loss: 1.4540
# Epoch 1: val_accuracy improved from None to 0.64147, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.4031 - loss: 1.3065 - val_accuracy: 0.6415 - val_loss: 0.8692 - learning_rate: 1.0000e-04
# Epoch 2/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5185 - loss: 1.0298
# Epoch 2: val_accuracy improved from 0.64147 to 0.78834, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.5642 - loss: 0.9633 - val_accuracy: 0.7883 - val_loss: 0.6852 - learning_rate: 1.0000e-04
# Epoch 3/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6534 - loss: 0.8004
# Epoch 3: val_accuracy improved from 0.78834 to 0.85097, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.6823 - loss: 0.7346 - val_accuracy: 0.8510 - val_loss: 0.5690 - learning_rate: 1.0000e-04
# Epoch 4/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7232 - loss: 0.6343
# Epoch 4: val_accuracy improved from 0.85097 to 0.90065, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.7412 - loss: 0.6082 - val_accuracy: 0.9006 - val_loss: 0.4847 - learning_rate: 1.0000e-04
# Epoch 5/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7995 - loss: 0.5080
# Epoch 5: val_accuracy improved from 0.90065 to 0.92333, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.8114 - loss: 0.4919 - val_accuracy: 0.9233 - val_loss: 0.4377 - learning_rate: 1.0000e-04
# Epoch 6/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8399 - loss: 0.4214
# Epoch 6: val_accuracy improved from 0.92333 to 0.93844, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.8434 - loss: 0.4139 - val_accuracy: 0.9384 - val_loss: 0.3860 - learning_rate: 1.0000e-04
# Epoch 7/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8690 - loss: 0.3691
# Epoch 7: val_accuracy improved from 0.93844 to 0.94492, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.8732 - loss: 0.3602 - val_accuracy: 0.9449 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 8/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8885 - loss: 0.3211
# Epoch 8: val_accuracy improved from 0.94492 to 0.95140, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.8900 - loss: 0.3192 - val_accuracy: 0.9514 - val_loss: 0.3451 - learning_rate: 1.0000e-04
# Epoch 9/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8956 - loss: 0.3078
# Epoch 9: val_accuracy improved from 0.95140 to 0.96004, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.9000 - loss: 0.2962 - val_accuracy: 0.9600 - val_loss: 0.3245 - learning_rate: 1.0000e-04
# Epoch 10/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9185 - loss: 0.2525
# Epoch 10: val_accuracy did not improve from 0.96004
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.9133 - loss: 0.2608 - val_accuracy: 0.9600 - val_loss: 0.3148 - learning_rate: 1.0000e-04
# Epoch 11/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9156 - loss: 0.2501
# Epoch 11: val_accuracy improved from 0.96004 to 0.96112, saving model to best_densenet_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.9175 - loss: 0.2450 - val_accuracy: 0.9611 - val_loss: 0.3010 - learning_rate: 1.0000e-04
# Epoch 12/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9304 - loss: 0.2131
# Epoch 12: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.9279 - loss: 0.2185 - val_accuracy: 0.9579 - val_loss: 0.2974 - learning_rate: 1.0000e-04
# Epoch 13/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9364 - loss: 0.2061
# Epoch 13: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9411 - loss: 0.1971 - val_accuracy: 0.9525 - val_loss: 0.2858 - learning_rate: 1.0000e-04
# Epoch 14/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9368 - loss: 0.2018
# Epoch 14: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9369 - loss: 0.2000 - val_accuracy: 0.9471 - val_loss: 0.2882 - learning_rate: 1.0000e-04
# Epoch 15/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9526 - loss: 0.1751
# Epoch 15: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.9482 - loss: 0.1835 - val_accuracy: 0.9482 - val_loss: 0.2796 - learning_rate: 1.0000e-04
# Epoch 16/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9406 - loss: 0.1789
# Epoch 16: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9492 - loss: 0.1700 - val_accuracy: 0.9417 - val_loss: 0.2862 - learning_rate: 1.0000e-04
# Epoch 17/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9487 - loss: 0.1662
# Epoch 17: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9524 - loss: 0.1605 - val_accuracy: 0.9514 - val_loss: 0.2672 - learning_rate: 1.0000e-04
# Epoch 18/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9509 - loss: 0.1644
# Epoch 18: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.9505 - loss: 0.1613 - val_accuracy: 0.9503 - val_loss: 0.2617 - learning_rate: 1.0000e-04
# Epoch 19/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9676 - loss: 0.1223
# Epoch 19: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9592 - loss: 0.1392 - val_accuracy: 0.9320 - val_loss: 0.2742 - learning_rate: 1.0000e-04
# Epoch 20/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9563 - loss: 0.1409
# Epoch 20: val_accuracy did not improve from 0.96112
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9573 - loss: 0.1384 - val_accuracy: 0.9374 - val_loss: 0.2730 - learning_rate: 1.0000e-04
# Epoch 21/50
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9559 - loss: 0.1479
# Epoch 21: val_accuracy did not improve from 0.96112
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9573 - loss: 0.1397 - val_accuracy: 0.9384 - val_loss: 0.2703 - learning_rate: 3.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 18.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9175 - loss: 0.2931
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Test Accuracy: 91.75%
# ✅ Test Loss: 0.2931
# 💾 Model saved as 'densenet121_disease_final.h5'

# %%
# ============================================================
# 🍃 DenseNet121 — Testing Accuracy on Test Dataset
# ============================================================

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# ============================================================
# Paths
# ============================================================
test_dir = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\GuavaDiseaseDataset\test"
model_path = "best_densenet_disease.h5"  # or "densenet121_disease_final.h5"

# ============================================================
# Load Saved Model
# ============================================================
model = load_model(model_path)
print("✅ Loaded model successfully!")

# ============================================================
# Test Data Generator
# ============================================================
img_size = (224, 224)
batch_size = 32

test_datagen = ImageDataGenerator(rescale=1./255)
test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ============================================================
# Evaluate Model on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n🎯 Test Accuracy: {test_acc*100:.2f}%")
print(f"📉 Test Loss: {test_loss:.4f}")

# ============================================================
# Detailed Classification Report
# ============================================================
y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_labels))

# ============================================================
# Confusion Matrix
# ============================================================
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix — DenseNet121 (Test Set)")
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Loaded model successfully!
# Found 473 images belonging to 3 classes.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.9133 - loss: 0.3492
#
# 🎯 Test Accuracy: 91.33%
# 📉 Test Loss: 0.3492
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step
#
# 📊 Classification Report:
#                          precision    recall  f1-score   support
#
#   Anthracnose_augmented       0.85      0.98      0.91       156
#     fruit_fly_augmented       0.91      0.89      0.90       131
# healthy_guava_augmented       0.99      0.88      0.93       186
#
#                accuracy                           0.91       473
#               macro avg       0.91      0.91      0.91       473
#            weighted avg       0.92      0.91      0.91       473
