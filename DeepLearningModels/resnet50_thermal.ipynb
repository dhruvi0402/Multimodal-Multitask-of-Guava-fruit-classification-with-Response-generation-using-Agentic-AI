# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorflow) (2.2.6)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Using cached markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.17.0-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cl502_15\appdata\local\anaconda3\envs\pytorch_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp311-cp311-win_amd64.whl (331.8 MB)
#    ---------------------------------------- 0.0/331.8 MB ? eta -:--:--
#    - -------------------------------------- 9.7/331.8 MB 50.2 MB/s eta 0:00:07
#    - -------------------------------------- 16.0/331.8 MB 38.7 MB/s eta 0:00:09
#    -- ------------------------------------- 23.1/331.8 MB 37.4 MB/s eta 0:00:09
#    --- ------------------------------------ 29.4/331.8 MB 35.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 34.1/331.8 MB 32.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 37.7/331.8 MB 30.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 42.2/331.8 MB 28.9 MB/s eta 0:00:11
#    ----- ---------------------------------- 47.4/331.8 MB 28.5 MB/s eta 0:00:10
#    ------ --------------------------------- 53.7/331.8 MB 28.5 MB/s eta 0:00:10
#    ------- -------------------------------- 61.3/331.8 MB 29.2 MB/s eta 0:00:10
#    -------- ------------------------------- 69.2/331.8 MB 29.8 MB/s eta 0:00:09
#    --------- ------------------------------ 77.9/331.8 MB 30.8 MB/s eta 0:00:09
#    ---------- ----------------------------- 85.2/331.8 MB 31.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 93.1/331.8 MB 31.4 MB/s eta 0:00:08
#    ----------- --------------------------- 101.7/331.8 MB 32.0 MB/s eta 0:00:08
#    ------------- ------------------------- 111.7/331.8 MB 32.9 MB/s eta 0:00:07
#    ------------- ------------------------- 116.9/331.8 MB 32.5 MB/s eta 0:00:07
#    -------------- ------------------------ 121.4/331.8 MB 31.6 MB/s eta 0:00:07
#    -------------- ------------------------ 125.0/331.8 MB 31.0 MB/s eta 0:00:07
#    --------------- ----------------------- 129.8/331.8 MB 30.5 MB/s eta 0:00:07
#    --------------- ----------------------- 135.0/331.8 MB 30.3 MB/s eta 0:00:07
#    ---------------- ---------------------- 141.6/331.8 MB 30.2 MB/s eta 0:00:07
#    ----------------- --------------------- 148.6/331.8 MB 30.3 MB/s eta 0:00:07
#    ------------------ -------------------- 155.5/331.8 MB 30.5 MB/s eta 0:00:06
#    ------------------- ------------------- 161.7/331.8 MB 30.4 MB/s eta 0:00:06
#    ------------------- ------------------- 169.3/331.8 MB 30.6 MB/s eta 0:00:06
#    -------------------- ------------------ 176.2/331.8 MB 30.7 MB/s eta 0:00:06
#    --------------------- ----------------- 182.7/331.8 MB 30.6 MB/s eta 0:00:05
#    ---------------------- ---------------- 190.1/331.8 MB 30.8 MB/s eta 0:00:05
#    ----------------------- --------------- 196.3/331.8 MB 30.8 MB/s eta 0:00:05
#    ----------------------- --------------- 200.0/331.8 MB 30.4 MB/s eta 0:00:05
#    ----------------------- --------------- 203.9/331.8 MB 30.0 MB/s eta 0:00:05
#    ------------------------ -------------- 208.7/331.8 MB 29.8 MB/s eta 0:00:05
#    ------------------------- ------------- 214.7/331.8 MB 29.8 MB/s eta 0:00:04
#    ------------------------- ------------- 220.2/331.8 MB 29.6 MB/s eta 0:00:04
#    -------------------------- ------------ 224.1/331.8 MB 29.4 MB/s eta 0:00:04
#    -------------------------- ------------ 226.0/331.8 MB 28.8 MB/s eta 0:00:04
#    -------------------------- ------------ 228.9/331.8 MB 28.4 MB/s eta 0:00:04
#    --------------------------- ----------- 232.5/331.8 MB 28.0 MB/s eta 0:00:04
#    --------------------------- ----------- 237.2/331.8 MB 27.9 MB/s eta 0:00:04
#    ---------------------------- ---------- 241.4/331.8 MB 27.7 MB/s eta 0:00:04
#    ---------------------------- ---------- 245.9/331.8 MB 27.6 MB/s eta 0:00:04
#    ----------------------------- --------- 251.7/331.8 MB 27.6 MB/s eta 0:00:03
#    ------------------------------ -------- 258.2/331.8 MB 27.6 MB/s eta 0:00:03
#    ------------------------------- ------- 265.6/331.8 MB 27.6 MB/s eta 0:00:03
#    -------------------------------- ------ 273.2/331.8 MB 27.5 MB/s eta 0:00:03
#    --------------------------------- ----- 282.1/331.8 MB 27.7 MB/s eta 0:00:02
#    ---------------------------------- ---- 291.5/331.8 MB 28.0 MB/s eta 0:00:02
#    ----------------------------------- --- 299.1/331.8 MB 28.6 MB/s eta 0:00:02
#    ------------------------------------ -- 307.5/331.8 MB 29.0 MB/s eta 0:00:01
#    ------------------------------------- - 317.5/331.8 MB 29.4 MB/s eta 0:00:01
#    --------------------------------------  326.6/331.8 MB 29.6 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 29.5 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 29.5 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 29.5 MB/s eta 0:00:01
#    ---------------------------------------- 331.8/331.8 MB 27.4 MB/s  0:00:11
# Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -------------------------- ------------- 3.1/4.7 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 13.6 MB/s  0:00:00
# Downloading ml_dtypes-0.5.3-cp311-cp311-win_amd64.whl (206 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp311-cp311-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------------------------- ------- 2.4/2.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 9.3 MB/s  0:00:00
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 9.7 MB/s  0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-2.0.0-cp311-cp311-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp311-cp311-win_amd64.whl (313 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt_einsum, ml_dtypes, mdurl, markdown, h5py, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow
#
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    ----- ----------------------------------  3/24 [wrapt]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    -------- -------------------------------  5/24 [termcolor]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ------------- --------------------------  8/24 [optree]
#    --------------- ------------------------  9/24 [opt_einsum]
#    --------------- ------------------------  9/24 [opt_einsum]
#    ---------------- ----------------------- 10/24 [ml_dtypes]
#    -------------------- ------------------- 12/24 [markdown]
#    -------------------- ------------------- 12/24 [markdown]
#    -------------------- ------------------- 12/24 [markdown]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ------------------------- -------------- 15/24 [google_pasta]
#    ------------------------- -------------- 15/24 [google_pasta]
#    -------------------------- ------------- 16/24 [gast]
#    ------------------------------ --------- 18/24 [absl-py]
#    ------------------------------ --------- 18/24 [absl-py]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    ---------------------------------------- 24/24 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 libclang-18.1.1 markdown-3.9 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 protobuf-6.33.0 rich-14.2.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 werkzeug-3.1.3 wrapt-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# ============================================================
# 🍃 Guava Maturity Classification using ResNet50 (Thermal Images)
# ============================================================

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os

# ============================================================
# Check for GPU / CUDA
# ============================================================
print("🔍 TensorFlow Version:", tf.__version__)
print("🚀 GPU Available:", tf.config.list_physical_devices('GPU'))

# ============================================================
# Paths to dataset
# ============================================================
train_dir = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split  thermal\train"
val_dir   = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split  thermal\val"
test_dir  = r"C:\Users\cl502_15\Downloads\Mtech Major Project\Mtech Major Project\Dataset\Maturity\train test val split  thermal\test"

# ============================================================
# Image parameters
# ============================================================
img_size = (224, 224)
batch_size = 32
epochs = 50

# ============================================================
# Data Generators (preprocessed)
# ============================================================
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen  = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ============================================================
# Model Definition — ResNet50
# ============================================================
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base model layers
for layer in base_model.layers:
    layer.trainable = False

# Custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.4)(x)
output = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# Callbacks
# ============================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,  # stop training if val_loss doesn't improve for 3 epochs
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'thermal_best_resnet50_guava.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,  # wait 2 epochs before reducing LR
    verbose=1,
    min_lr=1e-6
)

# ============================================================
# Training
# ============================================================
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    callbacks=[early_stop, checkpoint, reduce_lr]
)

# ============================================================
# Evaluation on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# ============================================================
# Save final model
# ============================================================
model.save("thermal_resnet50_guava_final.h5")
print("💾 Model saved as 'thermal_resnet50_guava_final.h5'")

# ============================================================
# Plot training history
# ============================================================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('ResNet50 Guava Thermal Classification Accuracy')
plt.show()
# Out:
# 🔍 TensorFlow Version: 2.20.0
# 🚀 GPU Available: []
# Found 6639 images belonging to 3 classes.
# Found 1421 images belonging to 3 classes.
# Found 1427 images belonging to 3 classes.
# Epoch 1/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3422 - loss: 1.2264
# Epoch 1: val_accuracy improved from None to 0.35327, saving model to thermal_best_resnet50_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 304s 1s/step - accuracy: 0.3401 - loss: 1.2168 - val_accuracy: 0.3533 - val_loss: 1.0930 - learning_rate: 1.0000e-04
# Epoch 2/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3430 - loss: 1.1796
# Epoch 2: val_accuracy improved from 0.35327 to 0.36524, saving model to thermal_best_resnet50_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3404 - loss: 1.1741 - val_accuracy: 0.3652 - val_loss: 1.0926 - learning_rate: 1.0000e-04
# Epoch 3/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3445 - loss: 1.1487
# Epoch 3: val_accuracy did not improve from 0.36524
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.3439 - loss: 1.1467 - val_accuracy: 0.3652 - val_loss: 1.0920 - learning_rate: 1.0000e-04
# Epoch 4/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3524 - loss: 1.1240
# Epoch 4: val_accuracy improved from 0.36524 to 0.36946, saving model to thermal_best_resnet50_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.3472 - loss: 1.1285 - val_accuracy: 0.3695 - val_loss: 1.0918 - learning_rate: 1.0000e-04
# Epoch 5/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3460 - loss: 1.1219
# Epoch 5: val_accuracy did not improve from 0.36946
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.3493 - loss: 1.1192 - val_accuracy: 0.3533 - val_loss: 1.0919 - learning_rate: 1.0000e-04
# Epoch 6/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3514 - loss: 1.1171
# Epoch 6: val_accuracy improved from 0.36946 to 0.39198, saving model to thermal_best_resnet50_guava.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.3508 - loss: 1.1154 - val_accuracy: 0.3920 - val_loss: 1.0911 - learning_rate: 1.0000e-04
# Epoch 7/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3673 - loss: 1.1040
# Epoch 7: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - accuracy: 0.3559 - loss: 1.1091 - val_accuracy: 0.3652 - val_loss: 1.0919 - learning_rate: 1.0000e-04
# Epoch 8/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3589 - loss: 1.1052
# Epoch 8: val_accuracy did not improve from 0.39198
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3653 - loss: 1.1033 - val_accuracy: 0.3652 - val_loss: 1.0922 - learning_rate: 1.0000e-04
# Epoch 9/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3625 - loss: 1.1019
# Epoch 9: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.3675 - loss: 1.1024 - val_accuracy: 0.3695 - val_loss: 1.0903 - learning_rate: 3.0000e-05
# Epoch 10/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3645 - loss: 1.1051
# Epoch 10: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - accuracy: 0.3624 - loss: 1.1050 - val_accuracy: 0.3652 - val_loss: 1.0904 - learning_rate: 3.0000e-05
# Epoch 11/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3505 - loss: 1.1044
# Epoch 11: val_accuracy did not improve from 0.39198
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.3568 - loss: 1.1037 - val_accuracy: 0.3652 - val_loss: 1.0903 - learning_rate: 3.0000e-05
# Epoch 12/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3519 - loss: 1.1010
# Epoch 12: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 296s 1s/step - accuracy: 0.3615 - loss: 1.1010 - val_accuracy: 0.3688 - val_loss: 1.0901 - learning_rate: 9.0000e-06
# Epoch 13/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3490 - loss: 1.1051
# Epoch 13: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 306s 1s/step - accuracy: 0.3476 - loss: 1.1040 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 9.0000e-06
# Epoch 14/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3440 - loss: 1.1070
# Epoch 14: val_accuracy did not improve from 0.39198
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.3553 - loss: 1.1031 - val_accuracy: 0.3681 - val_loss: 1.0900 - learning_rate: 9.0000e-06
# Epoch 15/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3459 - loss: 1.1052
# Epoch 15: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - accuracy: 0.3540 - loss: 1.1023 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 2.7000e-06
# Epoch 16/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3663 - loss: 1.1015
# Epoch 16: val_accuracy did not improve from 0.39198
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.3644 - loss: 1.1000 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 2.7000e-06
# Epoch 17/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3639 - loss: 1.1025
# Epoch 17: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.3601 - loss: 1.1017 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 18/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3524 - loss: 1.1035
# Epoch 18: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.3555 - loss: 1.1017 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 19/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3594 - loss: 1.1049
# Epoch 19: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.3648 - loss: 1.1031 - val_accuracy: 0.3695 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 20/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3647 - loss: 1.0992
# Epoch 20: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - accuracy: 0.3595 - loss: 1.1037 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 21/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3552 - loss: 1.1026
# Epoch 21: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.3516 - loss: 1.1033 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 22/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3543 - loss: 1.1038
# Epoch 22: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.3577 - loss: 1.1002 - val_accuracy: 0.3681 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 23/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3740 - loss: 1.0996
# Epoch 23: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 306s 1s/step - accuracy: 0.3644 - loss: 1.1021 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 24/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3526 - loss: 1.1016
# Epoch 24: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3574 - loss: 1.1011 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 25/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3710 - loss: 1.1013
# Epoch 25: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - accuracy: 0.3731 - loss: 1.1010 - val_accuracy: 0.3681 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 26/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3507 - loss: 1.1045
# Epoch 26: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.3495 - loss: 1.1042 - val_accuracy: 0.3688 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 27/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3554 - loss: 1.1008
# Epoch 27: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3561 - loss: 1.1007 - val_accuracy: 0.3673 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 28/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3420 - loss: 1.1073
# Epoch 28: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - accuracy: 0.3583 - loss: 1.0988 - val_accuracy: 0.3673 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 29/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3481 - loss: 1.1001
# Epoch 29: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.3555 - loss: 1.1000 - val_accuracy: 0.3681 - val_loss: 1.0900 - learning_rate: 1.0000e-06
# Epoch 30/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3531 - loss: 1.1026
# Epoch 30: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.3547 - loss: 1.1019 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 31/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3622 - loss: 1.1033
# Epoch 31: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 304s 1s/step - accuracy: 0.3558 - loss: 1.1025 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 32/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3724 - loss: 1.1006
# Epoch 32: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.3662 - loss: 1.1001 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 33/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3562 - loss: 1.0990
# Epoch 33: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 302s 1s/step - accuracy: 0.3580 - loss: 1.1015 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 34/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3488 - loss: 1.1004
# Epoch 34: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.3505 - loss: 1.1014 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 35/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3603 - loss: 1.1016
# Epoch 35: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.3540 - loss: 1.1023 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 36/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3674 - loss: 1.1022
# Epoch 36: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 307s 1s/step - accuracy: 0.3659 - loss: 1.1014 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 37/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3505 - loss: 1.1005
# Epoch 37: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.3467 - loss: 1.1028 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 38/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3520 - loss: 1.1002
# Epoch 38: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.3570 - loss: 1.0994 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 39/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3635 - loss: 1.0985
# Epoch 39: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 314s 2s/step - accuracy: 0.3624 - loss: 1.1001 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 40/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3531 - loss: 1.1048
# Epoch 40: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.3516 - loss: 1.1030 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 41/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3534 - loss: 1.1001
# Epoch 41: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.3519 - loss: 1.1007 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 42/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3694 - loss: 1.1002
# Epoch 42: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 318s 2s/step - accuracy: 0.3662 - loss: 1.0981 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 43/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3633 - loss: 1.0969
# Epoch 43: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.3635 - loss: 1.0994 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 44/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3562 - loss: 1.0975
# Epoch 44: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 301s 1s/step - accuracy: 0.3620 - loss: 1.0981 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 45/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3607 - loss: 1.1000
# Epoch 45: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.3623 - loss: 1.0993 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 46/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3541 - loss: 1.1022
# Epoch 46: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.3556 - loss: 1.1028 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 47/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3431 - loss: 1.1082
# Epoch 47: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 321s 2s/step - accuracy: 0.3553 - loss: 1.1022 - val_accuracy: 0.3673 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 48/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3740 - loss: 1.0950
# Epoch 48: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.3638 - loss: 1.1000 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 49/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3793 - loss: 1.0934
# Epoch 49: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.3678 - loss: 1.0982 - val_accuracy: 0.3681 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Epoch 50/50
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3592 - loss: 1.0966
# Epoch 50: val_accuracy did not improve from 0.39198
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 302s 1s/step - accuracy: 0.3609 - loss: 1.0990 - val_accuracy: 0.3688 - val_loss: 1.0899 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 50.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.3693 - loss: 1.0901
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Test Accuracy: 36.93%
# ✅ Test Loss: 1.0901
# 💾 Model saved as 'thermal_resnet50_guava_final.h5'

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
import seaborn as sns

# ============================================================
# ✅ Evaluate and Get Predictions on Test Set
# ============================================================
test_loss, test_acc = model.evaluate(test_gen)
print(f"\n🎯 Test Accuracy: {test_acc*100:.2f}%")
print(f"🧮 Test Loss: {test_loss:.4f}")

# Predict class probabilities
y_pred = model.predict(test_gen)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.classes

# ============================================================
# ✅ Classification Report
# ============================================================
print("\n📊 Classification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=list(test_gen.class_indices.keys())))

# ============================================================
# ✅ Confusion Matrix
# ============================================================
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=list(test_gen.class_indices.keys()), 
            yticklabels=list(test_gen.class_indices.keys()))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Test Set')
plt.show()

# ============================================================
# ✅ Overall Accuracy Score
# ============================================================
acc = accuracy_score(y_true, y_pred_classes)
print(f"✅ Final Test Accuracy Score: {acc*100:.2f}%")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.3693 - loss: 1.0901
#
# 🎯 Test Accuracy: 36.93%
# 🧮 Test Loss: 1.0901
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step
#
# 📊 Classification Report:
#
#               precision    recall  f1-score   support
#
#     immature       0.37      0.99      0.54       521
#       mature       0.64      0.02      0.03       504
#  semi_mature       0.00      0.00      0.00       402
#
#     accuracy                           0.37      1427
#    macro avg       0.34      0.34      0.19      1427
# weighted avg       0.36      0.37      0.21      1427
# c:\Users\cl502_15\AppData\Local\anaconda3\envs\pytorch_env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\cl502_15\AppData\Local\anaconda3\envs\pytorch_env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\cl502_15\AppData\Local\anaconda3\envs\pytorch_env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ✅ Final Test Accuracy Score: 36.93%

# %%
# ============================================================
# ✅ Final Train & Validation Scores
# ============================================================
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

print("\n📈 Final Training Results:")
print(f"🟩 Train Accuracy: {final_train_acc*100:.2f}%")
print(f"🟩 Validation Accuracy: {final_val_acc*100:.2f}%")
print(f"🔹 Train Loss: {final_train_loss:.4f}")
print(f"🔹 Validation Loss: {final_val_loss:.4f}")
# Out:
# 📈 Final Training Results:
# 🟩 Train Accuracy: 36.09%
# 🟩 Validation Accuracy: 36.88%
# 🔹 Train Loss: 1.0990
# 🔹 Validation Loss: 1.0899
