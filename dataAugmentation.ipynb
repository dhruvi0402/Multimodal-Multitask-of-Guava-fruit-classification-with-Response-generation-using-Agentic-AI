# %%
pip install tensorflow
# Out:
# ...
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/331.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/331.7 MB 5.2 MB/s eta 0:01:04
#    ---------------------------------------- 0.5/331.7 MB 5.2 MB/s eta 0:01:04
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Diseased"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Diseased_Augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
pip install labelme
# Out:
# ...
#      ---------------------------------------- 0.0/68.4 kB ? eta -:--:--
#      ---------------------------------------- 68.4/68.4 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------ --------------------------- 0.4/1.4 MB 13.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.4 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.2 MB 17.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 13.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 15.0 MB/s eta 0:00:01
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\15cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\15cm_augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\30 cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\30cm_augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\45 cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Immature\45cm_augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\15cm drop"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\15cm drop augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\30cm drop"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\30cm drop augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\45cm drop"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Mature\45cm drop augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\15 cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\15 cm augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\30 cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\30 cm augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True)

input_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\45 cm"
output_dir = r"C:\Users\cl502_06\Documents\Mtech Major Project\Guava Fruit Dataset\Digital Images\Semi Mature\45 cm augmented"
os.makedirs(output_dir, exist_ok=True)

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

for filename in os.listdir(input_dir):
    img = load_img(os.path.join(input_dir, filename))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir=output_dir,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i > 10:  # generate 10 images per original
            break
